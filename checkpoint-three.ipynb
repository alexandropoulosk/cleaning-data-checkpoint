# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd #reads data
import numpy as np
import seaborn as sb # visualizations
import matplotlib.pyplot as plt # visualizations

# %%
df = pd.read_csv("C:\\Users\\Katerina\\OneDrive\\Documents\\LCW+ Assignments\\Final Project DA\\data\\posture_vs_personality.csv")

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0      1   53      62     125  Female            Low     0.0     0.0     0.0
# 1      2   52      69     157    Male           High     7.0     8.0     5.0
# 2      3   30      69     200    Male           High     0.0     0.0     0.0
# 3      4   51      66     175    Male       Moderate     9.5     9.5     9.5
# 4      5   45      63     199  Female       Moderate     4.0     5.0     2.0
# ..   ...  ...     ...     ...     ...            ...     ...     ...     ...
# 92    93   16      58     100    Male       Moderate     0.0     0.0     0.0
# 93    94   45      62     134  Female       Moderate     0.0     4.0     0.0
# 94    95   43      69     188    Male       Moderate     2.0     0.0     0.0
# 95    96   28      67     180  Female            Low     0.0     0.0     0.0
# 96    97   43      69     188    Male       Moderate     4.0     0.0     0.0
#
# ...

# %%
df.isnull()
# Out:
#      S No    AGE  HEIGHT  WEIGHT    SEX  ACTIVITY LEVEL  PAIN 1  PAIN 2  \
# 0   False  False   False   False  False           False   False   False
# 1   False  False   False   False  False           False   False   False
# 2   False  False   False   False  False           False   False   False
# 3   False  False   False   False  False           False   False   False
# 4   False  False   False   False  False           False   False   False
# ..    ...    ...     ...     ...    ...             ...     ...     ...
# 92  False  False   False   False  False           False   False   False
# 93  False  False   False   False  False           False   False   False
# 94  False  False   False   False  False           False   False   False
# 95  False  False   False   False  False           False   False   False
# 96  False  False   False   False  False           False   False   False
#
#     PAIN 3  PAIN 4   MBTI      E      I      S      N      T      F      J  \
# ...

# %%
# No missing data

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# S No - 0%
# AGE - 0%
# HEIGHT - 0%
# WEIGHT - 0%
# SEX - 0%
# ACTIVITY LEVEL - 0%
# PAIN 1 - 0%
# PAIN 2 - 0%
# PAIN 3 - 0%
# PAIN 4 - 0%
# MBTI - 0%
# E - 0%
# I - 0%
# S - 0%
# N - 0%
# T - 0%
# F - 0%
# J - 0%
# P - 0%
# POSTURE - 0%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S No            97 non-null     int64
#  1   AGE             97 non-null     int64
#  2   HEIGHT          97 non-null     int64
#  3   WEIGHT          97 non-null     int64
#  4   SEX             97 non-null     object
#  5   ACTIVITY LEVEL  97 non-null     object
#  6   PAIN 1          97 non-null     float64
#  7   PAIN 2          97 non-null     float64
#  8   PAIN 3          97 non-null     float64
#  9   PAIN 4          97 non-null     float64
#  10  MBTI            97 non-null     object
#  11  E               97 non-null     int64
#  12  I               97 non-null     int64
#  13  S               97 non-null     int64
#  14  N               97 non-null     int64
#  15  T               97 non-null     int64
#  16  F               97 non-null     int64
# ...

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
df.describe()
# Out:
#             S No        AGE     HEIGHT     WEIGHT     PAIN 1     PAIN 2  \
# count  97.000000  97.000000  97.000000   97.00000  97.000000  97.000000
# mean   49.000000  43.855670  65.731959  159.43299   2.139175   3.747423
# std    28.145456  16.776093   3.737522   36.19591   2.572635   3.191071
# min     1.000000  11.000000  58.000000   68.00000   0.000000   0.000000
# 25%    25.000000  30.000000  63.000000  135.00000   0.000000   0.000000
# 50%    49.000000  45.000000  66.000000  157.00000   1.000000   3.000000
# 75%    73.000000  56.000000  68.000000  183.00000   4.000000   7.000000
# max    97.000000  82.000000  74.000000  263.00000   9.500000  10.000000
#
#           PAIN 3     PAIN 4          E          I          S          N  \
# count  97.000000  97.000000  97.000000  97.000000  97.000000  97.000000
# mean    1.943299   2.530928  12.690722   8.288660  15.134021  11.041237
# std     2.587909   3.111483   5.717956   5.697146   4.833970   4.732242
# ...

# %%
df.columns
# Out:
# Index(['S No', 'AGE', 'HEIGHT', 'WEIGHT', 'SEX', 'ACTIVITY LEVEL', 'PAIN 1',
#        'PAIN 2', 'PAIN 3', 'PAIN 4', 'MBTI', 'E', 'I', 'S', 'N', 'T', 'F', 'J',
#        'P', 'POSTURE'],
#       dtype='object')

# %%
df.drop(['HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL', 'PAIN 1',
                    'PAIN 2', 'PAIN 3', 'PAIN 4',
                    'S', 'N', 'T', 'F', 'J', 'P'], axis=1, inplace=True)
df
# Out:
#     S No  AGE     SEX  MBTI   E   I POSTURE
# 0      1   53  Female  ESFJ  18   3       A
# 1      2   52    Male  ISTJ   6  15       B
# 2      3   30    Male  ESTJ  15   6       A
# 3      4   51    Male  ISTJ   6  15       D
# 4      5   45  Female  ENFJ  14   7       A
# ..   ...  ...     ...   ...  ..  ..     ...
# 92    93   16    Male  ESTP  19   2       B
# 93    94   45  Female  ESFJ  11  10       B
# 94    95   43    Male  ENFP  12   9       A
# 95    96   28  Female  ESFJ  11  10       B
# 96    97   43    Male  ENFP  12   9       A
#
# [97 rows x 7 columns]

# %%
# because I am only comparing posture to extrovert and introverts, i didnt 
#really need the other columns
#keeping the remaining columns for more context on the individuals

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
df.head(50)
# Out:
#     S No  AGE     SEX  MBTI   E   I POSTURE
# 0      1   53  Female  ESFJ  18   3       A
# 1      2   52    Male  ISTJ   6  15       B
# 2      3   30    Male  ESTJ  15   6       A
# 3      4   51    Male  ISTJ   6  15       D
# 4      5   45  Female  ENFJ  14   7       A
# 5      6   68    Male  ISFP   4  17       D
# 6      7   62    Male  ISTP   7  14       B
# 7      8   65  Female  ESTJ  17   4       D
# 8      9   66    Male  ESFJ  19   2       C
# 9     10   58    Male  INFJ   5  16       D
# 10    11   61    Male  ENTP  11  10       B
# 11    12   33  Female  ISFJ   2  19       B
# 12    13   48  Female  ESFJ  13   8       D
# 13    14   57    Male  ENTJ  16   5       B
# 14    15   30    Male  ESTP  20   1       A
# 15    16   62    Male  ISTJ   2  19       D
# 16    17   59  Female  ESTJ  12   9       A
# 17    18   33    Male  ENFP  17   4       B
# 18    19   23  Female  ESFP  13   8       B
# 19    20   48  Female  ISFP   9  13       C
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# Honestly - No. I just needed to remove some unnecessary data.
# 2. Did the process of cleaning your data give you new insights into your dataset?
# I feel like I had a good handle of my data since the checkpoint 2.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
# Not at the moment
